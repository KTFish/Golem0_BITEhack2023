# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("2017_2019.csv")
df.drop(['Unnamed: 18'],inplace=True,axis=1)

# %%
dates = set()
for i,data in df.iterrows():
    dates.add(pd.to_datetime( 
                             str(data['Year'])[:-2]+'-'+str(data['Month'])[:-2] + '-' + str(data['Day'])[:-2],
                             format="%Y-%m-%d"
                             ))

# %%
def get_day(df:pd.DataFrame,day:pd.Timestamp) -> pd.DataFrame:
    
    return df.loc[ (df ['Year'] == day.year) & 
                  (df['Day'] == day.day) &
                  (df['Month'] == day.month)]
    
def get_records_night(df:pd.DataFrame,day:pd.Timestamp):
    records_beafore_df = get_n_days_beafore(df,day,1)
    records_beafore_df = records_beafore_df.loc[(records_beafore_df.Hour > 12)  & (records_beafore_df["Clearsky DNI"] != 0)]
    
    records_df = get_day(df,day)
    records_df = records_df.loc[(records_df.Hour < 12) &( records_df.DNI == 0) &(records_df["Clearsky DNI"] != 0)]
    
    return(pd.concat([records_beafore_df,records_df]))
    
def get_n_days_beafore(df:pd.DataFrame,day:pd.Timestamp,n:int):
    day_beafore = day - pd.offsets.Day(n)
    return get_day(df,day_beafore)

def get_working_day(df:pd.DataFrame,day:pd.Timestamp):
    records = get_day(df,day)
    return records.loc[(records.DNI != 0) | (records["Clearsky DNI"] != 0)]

# %%
_ = pd.Series( list(dates)).sort_values()
get_records_night(df,_.iloc[2])
# Out:
#      Year  Month  Day  Hour  Minute  Temperature  Clearsky DHI  Clearsky DNI  \
# 148  2017      1    2    13       0          7.5            69           738
# 149  2017      1    2    13      15          7.2            65           702
# 150  2017      1    2    13      30          6.8            60           658
# 151  2017      1    2    13      45          6.5            54           610
# 152  2017      1    2    14       0          6.1            48           542
# 153  2017      1    2    14      15          6.0            40           455
# 154  2017      1    2    14      30          5.9            31           342
# 155  2017      1    2    14      45          5.7            19           199
# 215  2017      1    3     5      45          3.8            19           155
# 216  2017      1    3     6       0          4.3            31           285
# 217  2017      1    3     6      15          4.8            42           391
# 218  2017      1    3     6      30          5.2            51           475
# 219  2017      1    3     6      45          5.7            58           545
# 220  2017      1    3     7       0          6.1            64           600
#
#      Clearsky GHI  Dew Point  DHI  DNI  GHI  Relative Humidity  \
# 148           296       -1.7   69  738  296              52.30
# 149           258       -1.7   65  702  258              53.38
# 150           219       -1.7   60  658  219              54.86
# 151           179       -2.4   54  610  179              52.89
# 152           138       -2.4   48  542  138              54.36
# 153            98       -2.4   40  455   98              54.74
# 154            60       -2.4   31  342   60              55.12
# 155            28       -3.1   19  199   28              52.99
# 215            25        0.7    9    0    9              80.07
# 216            55        0.7   20    0   20              77.31
# 217            91        0.7   33    0   33              74.74
# 218           129        0.7   48    0   48              72.69
# 219           169        1.2   65    0   65              72.65
# 220           208        1.2   83    0   83              70.67
#
#      Solar Zenith Angle  Surface Albedo  Pressure  Wind Speed
# 148               72.09            0.13      1000         0.9
# 149               74.03            0.13      1000         0.8
# 150               76.07            0.13      1000         0.8
# 151               78.21            0.13      1000         0.8
# 152               80.44            0.13      1000         0.7
# 153               82.74            0.13      1000         0.7
# 154               85.11            0.13      1000         0.6
# 155               87.49            0.13      1000         0.6
# 215               87.59            0.13      1000         3.0
# 216               85.21            0.13      1000         3.1
# 217               82.84            0.13      1001         3.2
# 218               80.53            0.13      1001         3.4
# 219               78.29            0.13      1001         3.5
# 220               76.14            0.13      1001         3.6

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Year, Month, Day, Hour, Minute, Temperature, Clearsky DHI, Clearsky DNI, Clearsky GHI, Dew Point, DHI, DNI, GHI, Relative Humidity, Solar Zenith Angle, Surface Albedo, Pressure, Wind Speed]
# Index: []

# %%
records_df =pd.DataFrame()
for idx,date in enumerate( pd.Series( list(dates)).sort_values().values):
    
    date = pd.to_datetime(date)
    day = get_working_day(df,date)
    record = pd.DataFrame([{'date':date}])
    
    record['month'] = date.month
    record['len_day'] = len(day)
    record['temp_mean'] = day.Temperature.mean()
    record['press_mean'] = day.Pressure.mean()
    record['wind_mean'] = day["Wind Speed"].mean()
    
    
    night = get_records_night(df,date)
    
    if idx == 0:
        record['len_night'] = 0
    else:
        record['len_night'] = len(night)
        record['night_temp_mean'] = night.Temperature.mean()
        record['night_press_mean'] = night.Pressure.mean()
        record['night_wind_mean'] = night["Wind Speed"].mean()
    
    record['Y'] = (day["Clearsky DNI"].sum() + day['DNI'].sum()) / record['len_day']
    records_df = pd.concat([records_df,record])
records_df
# Out:
#          date  month  len_day  temp_mean   press_mean  wind_mean  len_night  \
# 0  2017-01-01      1       37   4.910811  1001.648649   1.878378          0
# 0  2017-01-02      1       37   6.035135  1000.918919   1.335135         11
# 0  2017-01-03      1       37   8.983784   999.756757   2.970270         14
# 0  2017-01-04      1       37  10.167568   996.621622   3.432432         15
# 0  2017-01-05      1       37  14.021622   988.594595   6.070270         26
# ..        ...    ...      ...        ...          ...        ...        ...
# 0  2019-12-27     12       37   8.959459   996.324324   3.143243          8
# 0  2019-12-28     12       37   8.727027   991.810811   1.532432         22
# 0  2019-12-29     12       37   7.818919   992.486486   4.994595         19
# 0  2019-12-30     12       37   7.432432   987.621622   6.756757         33
# 0  2019-12-31     12       37   9.537838   999.378378   3.497297          8
#
#               Y  night_temp_mean  night_press_mean  night_wind_mean
# 0   1397.243243              NaN               NaN              NaN
# 0   1391.621622         3.863636       1000.727273         1.709091
# 0   1068.054054         5.828571       1000.285714         1.835714
# 0    685.891892         8.826667        998.400000         2.533333
# 0    538.972973        12.834615        990.846154         5.188462
# ..          ...              ...               ...              ...
# 0   1206.540541         9.762500        989.875000         3.962500
# 0    595.216216         8.468182        993.545455         1.740909
# 0    636.756757         6.684211        992.157895         3.405263
# 0    566.675676         7.439394        988.303030         6.748485
# 0   1232.054054         7.487500        989.125000         4.712500
#
# [1095 rows x 11 columns]

# %%
records_df = records_df.iloc[1:-1]

# %%
records_df.head()
# Out:
#         date  month  len_day  temp_mean   press_mean  wind_mean  len_night  \
# 0 2017-01-02      1       37   6.035135  1000.918919   1.335135         11
# 0 2017-01-03      1       37   8.983784   999.756757   2.970270         14
# 0 2017-01-04      1       37  10.167568   996.621622   3.432432         15
# 0 2017-01-05      1       37  14.021622   988.594595   6.070270         26
# 0 2017-01-06      1       37  13.254054   983.567568   9.543243         33
#
#              Y  night_temp_mean  night_press_mean  night_wind_mean
# 0  1391.621622         3.863636       1000.727273         1.709091
# 0  1068.054054         5.828571       1000.285714         1.835714
# 0   685.891892         8.826667        998.400000         2.533333
# 0   538.972973        12.834615        990.846154         5.188462
# 0   474.270270        13.800000        985.090909         9.306061

# %%
def get_Data_n_records(df,num):
    X = []
    Y = []
    for i in range(len(df)):
        if i < num+1:
            pass
        else:
            X.append(df.iloc[i-num-1:i-1].values)
            Y.append(df.iloc[i].Y)
    return np.array(X),np.array(Y)

X,Y = get_Data_n_records(records_df,10)

# %%
import pandas as pd
import numpy as np 
import keras as kr
import sklearn as skl
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
import tensorflow as tf
from sklearn.preprocessing import normalize

# %%
records_df.drop(["date"], inplace= True,axis= 1)
records_df.dropna(inplace=True)
# Out:
# C:\Users\wpiot\AppData\Local\Temp\ipykernel_21800\2666662145.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   records_df.drop(["date"], inplace= True,axis= 1)
# C:\Users\wpiot\AppData\Local\Temp\ipykernel_21800\2666662145.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   records_df.dropna(inplace=True)

# %%
records_df[records_df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [month, len_day, temp_mean, press_mean, wind_mean, len_night, Y, night_temp_mean, night_press_mean, night_wind_mean]
# Index: []

# %%
num = 30
X,Y = get_Data_n_records(records_df,num)
scaler = skl.preprocessing.MinMaxScaler(feature_range=(0, 1))
scaler.fit(records_df)


Y = pd.Series(Y)
Y=(Y-Y.min())/(Y.max()-Y.min())
x_train,x_test,y_train,y_test = train_test_split(X,Y)

# regr = RandomForestRegressor(random_state=0)
# regr.fit(x_train, y_train)

model = kr.Sequential()
model.add(kr.layers.LSTM(4, input_shape=(num, 10)))
model.add(kr.layers.Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
hist = model.fit(x_train, y_train, epochs=100, batch_size=32, verbose=2)


print(hist)
# Out:
# Epoch 1/100
# 25/25 - 3s - loss: 0.3832 - 3s/epoch - 106ms/step
# Epoch 2/100
# 25/25 - 0s - loss: 0.3044 - 316ms/epoch - 13ms/step
# Epoch 3/100
# 25/25 - 0s - loss: 0.2398 - 288ms/epoch - 12ms/step
# Epoch 4/100
# 25/25 - 0s - loss: 0.1886 - 297ms/epoch - 12ms/step
# Epoch 5/100
# 25/25 - 0s - loss: 0.1490 - 348ms/epoch - 14ms/step
# Epoch 6/100
# 25/25 - 0s - loss: 0.1189 - 303ms/epoch - 12ms/step
# Epoch 7/100
# 25/25 - 0s - loss: 0.0966 - 316ms/epoch - 13ms/step
# Epoch 8/100
# 25/25 - 0s - loss: 0.0804 - 302ms/epoch - 12ms/step
# Epoch 9/100
# 25/25 - 0s - loss: 0.0695 - 298ms/epoch - 12ms/step
# Epoch 10/100
# 25/25 - 0s - loss: 0.0617 - 302ms/epoch - 12ms/step
# Epoch 11/100
# 25/25 - 0s - loss: 0.0566 - 315ms/epoch - 13ms/step
# Epoch 12/100
# 25/25 - 0s - loss: 0.0534 - 303ms/epoch - 12ms/step
# Epoch 13/100
# 25/25 - 0s - loss: 0.0513 - 300ms/epoch - 12ms/step
# Epoch 14/100
# 25/25 - 0s - loss: 0.0501 - 315ms/epoch - 13ms/step
# Epoch 15/100
# 25/25 - 0s - loss: 0.0494 - 300ms/epoch - 12ms/step
# Epoch 16/100
# 25/25 - 0s - loss: 0.0490 - 369ms/epoch - 15ms/step
# Epoch 17/100
# 25/25 - 0s - loss: 0.0487 - 396ms/epoch - 16ms/step
# Epoch 18/100
# 25/25 - 0s - loss: 0.0486 - 330ms/epoch - 13ms/step
# Epoch 19/100
# 25/25 - 0s - loss: 0.0486 - 330ms/epoch - 13ms/step
# Epoch 20/100
# 25/25 - 0s - loss: 0.0485 - 348ms/epoch - 14ms/step
# Epoch 21/100
# 25/25 - 0s - loss: 0.0485 - 364ms/epoch - 15ms/step
# Epoch 22/100
# 25/25 - 0s - loss: 0.0485 - 336ms/epoch - 13ms/step
# Epoch 23/100
# 25/25 - 0s - loss: 0.0485 - 303ms/epoch - 12ms/step
# Epoch 24/100
# 25/25 - 0s - loss: 0.0485 - 304ms/epoch - 12ms/step
# Epoch 25/100
# 25/25 - 0s - loss: 0.0485 - 317ms/epoch - 13ms/step
# Epoch 26/100
# 25/25 - 0s - loss: 0.0485 - 341ms/epoch - 14ms/step
# Epoch 27/100
# 25/25 - 0s - loss: 0.0485 - 332ms/epoch - 13ms/step
# Epoch 28/100
# 25/25 - 0s - loss: 0.0485 - 371ms/epoch - 15ms/step
# Epoch 29/100
# 25/25 - 0s - loss: 0.0485 - 335ms/epoch - 13ms/step
# Epoch 30/100
# 25/25 - 0s - loss: 0.0485 - 325ms/epoch - 13ms/step
# Epoch 31/100
# 25/25 - 0s - loss: 0.0485 - 356ms/epoch - 14ms/step
# Epoch 32/100
# 25/25 - 0s - loss: 0.0485 - 385ms/epoch - 15ms/step
# Epoch 33/100
# 25/25 - 0s - loss: 0.0485 - 352ms/epoch - 14ms/step
# Epoch 34/100
# 25/25 - 0s - loss: 0.0485 - 332ms/epoch - 13ms/step
# Epoch 35/100
# 25/25 - 0s - loss: 0.0485 - 368ms/epoch - 15ms/step
# Epoch 36/100
# 25/25 - 0s - loss: 0.0485 - 331ms/epoch - 13ms/step
# Epoch 37/100
# 25/25 - 0s - loss: 0.0485 - 306ms/epoch - 12ms/step
# Epoch 38/100
# 25/25 - 0s - loss: 0.0485 - 321ms/epoch - 13ms/step
# Epoch 39/100
# 25/25 - 0s - loss: 0.0485 - 312ms/epoch - 12ms/step
# Epoch 40/100
# 25/25 - 0s - loss: 0.0485 - 378ms/epoch - 15ms/step
# Epoch 41/100
# 25/25 - 0s - loss: 0.0485 - 359ms/epoch - 14ms/step
# Epoch 42/100
# 25/25 - 0s - loss: 0.0485 - 372ms/epoch - 15ms/step
# Epoch 43/100
# 25/25 - 0s - loss: 0.0485 - 392ms/epoch - 16ms/step
# Epoch 44/100
# 25/25 - 0s - loss: 0.0485 - 440ms/epoch - 18ms/step
# Epoch 45/100
# 25/25 - 0s - loss: 0.0484 - 493ms/epoch - 20ms/step
# Epoch 46/100
# 25/25 - 0s - loss: 0.0484 - 483ms/epoch - 19ms/step
# Epoch 47/100
# 25/25 - 0s - loss: 0.0484 - 389ms/epoch - 16ms/step
# Epoch 48/100
# 25/25 - 0s - loss: 0.0484 - 353ms/epoch - 14ms/step
# Epoch 49/100
# 25/25 - 0s - loss: 0.0485 - 368ms/epoch - 15ms/step
# Epoch 50/100
# 25/25 - 0s - loss: 0.0485 - 351ms/epoch - 14ms/step
# Epoch 51/100
# 25/25 - 0s - loss: 0.0484 - 339ms/epoch - 14ms/step
# Epoch 52/100
# 25/25 - 0s - loss: 0.0484 - 321ms/epoch - 13ms/step
# Epoch 53/100
# 25/25 - 0s - loss: 0.0484 - 335ms/epoch - 13ms/step
# Epoch 54/100
# 25/25 - 0s - loss: 0.0485 - 335ms/epoch - 13ms/step
# Epoch 55/100
# 25/25 - 0s - loss: 0.0484 - 311ms/epoch - 12ms/step
# Epoch 56/100
# 25/25 - 0s - loss: 0.0484 - 327ms/epoch - 13ms/step
# Epoch 57/100
# 25/25 - 0s - loss: 0.0484 - 325ms/epoch - 13ms/step
# Epoch 58/100
# 25/25 - 0s - loss: 0.0484 - 335ms/epoch - 13ms/step
# Epoch 59/100
# 25/25 - 0s - loss: 0.0485 - 409ms/epoch - 16ms/step
# Epoch 60/100
# 25/25 - 0s - loss: 0.0484 - 324ms/epoch - 13ms/step
# Epoch 61/100
# 25/25 - 0s - loss: 0.0484 - 332ms/epoch - 13ms/step
# Epoch 62/100
# 25/25 - 0s - loss: 0.0484 - 332ms/epoch - 13ms/step
# Epoch 63/100
# 25/25 - 0s - loss: 0.0485 - 406ms/epoch - 16ms/step
# Epoch 64/100
# 25/25 - 0s - loss: 0.0484 - 327ms/epoch - 13ms/step
# Epoch 65/100
# 25/25 - 0s - loss: 0.0484 - 314ms/epoch - 13ms/step
# Epoch 66/100
# 25/25 - 0s - loss: 0.0484 - 338ms/epoch - 14ms/step
# Epoch 67/100
# 25/25 - 0s - loss: 0.0484 - 354ms/epoch - 14ms/step
# Epoch 68/100
# 25/25 - 0s - loss: 0.0485 - 371ms/epoch - 15ms/step
# Epoch 69/100
# 25/25 - 0s - loss: 0.0484 - 324ms/epoch - 13ms/step
# Epoch 70/100
# 25/25 - 0s - loss: 0.0484 - 398ms/epoch - 16ms/step
# Epoch 71/100
# 25/25 - 0s - loss: 0.0484 - 335ms/epoch - 13ms/step
# Epoch 72/100
# 25/25 - 0s - loss: 0.0484 - 395ms/epoch - 16ms/step
# Epoch 73/100
# 25/25 - 0s - loss: 0.0484 - 446ms/epoch - 18ms/step
# Epoch 74/100
# 25/25 - 0s - loss: 0.0484 - 328ms/epoch - 13ms/step
# Epoch 75/100
# 25/25 - 0s - loss: 0.0484 - 349ms/epoch - 14ms/step
# Epoch 76/100
# 25/25 - 0s - loss: 0.0484 - 402ms/epoch - 16ms/step
# Epoch 77/100
# 25/25 - 0s - loss: 0.0485 - 359ms/epoch - 14ms/step
# Epoch 78/100
# 25/25 - 0s - loss: 0.0485 - 331ms/epoch - 13ms/step
# Epoch 79/100
# 25/25 - 0s - loss: 0.0484 - 326ms/epoch - 13ms/step
# Epoch 80/100
# 25/25 - 0s - loss: 0.0484 - 329ms/epoch - 13ms/step
# Epoch 81/100
# 25/25 - 0s - loss: 0.0485 - 396ms/epoch - 16ms/step
# Epoch 82/100
# 25/25 - 0s - loss: 0.0484 - 359ms/epoch - 14ms/step
# Epoch 83/100
# 25/25 - 0s - loss: 0.0485 - 405ms/epoch - 16ms/step
# Epoch 84/100
# 25/25 - 0s - loss: 0.0485 - 367ms/epoch - 15ms/step
# Epoch 85/100
# 25/25 - 0s - loss: 0.0485 - 353ms/epoch - 14ms/step
# Epoch 86/100
# 25/25 - 0s - loss: 0.0486 - 421ms/epoch - 17ms/step
# Epoch 87/100
# 25/25 - 0s - loss: 0.0485 - 359ms/epoch - 14ms/step
# Epoch 88/100
# 25/25 - 0s - loss: 0.0484 - 329ms/epoch - 13ms/step
# Epoch 89/100
# 25/25 - 0s - loss: 0.0485 - 328ms/epoch - 13ms/step
# Epoch 90/100
# 25/25 - 0s - loss: 0.0485 - 344ms/epoch - 14ms/step
# Epoch 91/100
# 25/25 - 0s - loss: 0.0484 - 305ms/epoch - 12ms/step
# Epoch 92/100
# 25/25 - 0s - loss: 0.0484 - 313ms/epoch - 13ms/step
# Epoch 93/100
# 25/25 - 0s - loss: 0.0485 - 312ms/epoch - 12ms/step
# Epoch 94/100
# 25/25 - 0s - loss: 0.0484 - 312ms/epoch - 12ms/step
# Epoch 95/100
# 25/25 - 0s - loss: 0.0485 - 328ms/epoch - 13ms/step
# Epoch 96/100
# 25/25 - 0s - loss: 0.0484 - 313ms/epoch - 13ms/step
# Epoch 97/100
# 25/25 - 0s - loss: 0.0484 - 313ms/epoch - 13ms/step
# Epoch 98/100
# 25/25 - 0s - loss: 0.0484 - 313ms/epoch - 13ms/step
# Epoch 99/100
# 25/25 - 0s - loss: 0.0484 - 328ms/epoch - 13ms/step
# Epoch 100/100
# 25/25 - 0s - loss: 0.0484 - 388ms/epoch - 16ms/step
# <keras.callbacks.History object at 0x00000138D3A600A0>

# %%
y_test.values,mlp_model.predict(x_test)
# Out:
# 9/9 [==============================] - 0s 3ms/step
# (array([0.68863724, 0.89201708, 0.34828885, 0.18536334, 0.49206965,
#         0.79337458, 0.33010342, 0.86768661, 0.6776196 , 0.85236127,
#         0.77064038, 0.78175539, 0.61482975, 0.71058619, 0.73411518,
#         0.20982388, 0.66016762, 0.19049232, 0.11248425, 0.27279553,
#         0.84210514, 0.81876387, 0.68034771, 0.70572523, 0.4283241 ,
#         0.61319295, 0.75160331, 0.79510166, 0.73401028, 0.30341814,
#         0.75418803, 0.42306811, 0.83577676, 0.74387027, 0.75519991,
#         0.54457146, 0.62817577, 0.55632598, 0.80508238, 0.69652091,
#         0.85361501, 0.8614859 , 0.69872634, 0.84174174, 0.22653621,
#         0.63497911, 0.55752913, 0.69649293, 0.37532886, 0.68923589,
#         0.39118951, 0.72987074, 0.46113127, 0.67057277, 0.4783416 ,
#         0.44166924, 0.89518699, 0.70225351, 0.72840055, 0.19334796,
#         0.51327466, 0.72409277, 0.88309781, 0.73554362, 0.54338936,
#         0.8173643 , 0.30936255, 0.76958386, 0.81266506, 0.61284639,
#         0.47904473, 0.76166635, 0.57960353, 0.22942829, 0.59528838,
#         0.56113412, 0.46961773, 0.55125767, 0.68798391, 0.22509708,
#         0.83449752, 0.7639819 , 0.33114094, 0.58668793, 0.78648695,
#         0.31833893, 0.4856757 , 0.80614009, 0.85574782, 0.77466979,
#         0.86246557, 0.62678861, 0.1989078 , 0.55204233, 0.56585916,
#         0.74500941, 0.36365449, 0.31241374, 0.81386166, 0.60368554,
#         0.70996464, 0.0375921 , 0.81416084, 0.49595709, 0.83837555,
#         0.36625564, 0.43241787, 0.13216398, 0.14052349, 0.64716864,
#         0.32262236, 0.88011022, 0.7549916 , 0.83757407, 0.26688977,
#         0.50021032, 0.93079412, 0.89695841, 0.46682228, 0.77736369,
#         0.88521787, 0.29315051, 0.54964785, 0.30501096, 0.56886899,
#         0.72784079, 0.84153155, 0.26594847, 0.65834026, 0.44463983,
#         0.25092921, 0.42189908, 0.78692706, 0.84273233, 0.58319057,
#         0.30011595, 0.7359037 , 0.82057339, 0.35954943, 0.67490518,
#         0.29666016, 0.7177044 , 0.4245321 , 0.86025579, 0.60556916,
#         0.55828933, 0.29128081, 0.1603493 , 0.85568739, 0.62834073,
#         0.30372089, 0.20705638, 0.69061927, 0.67799099, 0.78797586,
#         0.75826187, 0.60140431, 0.29470606, 0.60361128, 0.85644879,
#         0.6747079 , 0.1785389 , 0.59046328, 0.42473464, 0.74406729,
#         0.81897553, 0.28480141, 0.8653318 , 0.93450323, 0.80892434,
#         0.80943087, 0.3264131 , 0.71023477, 0.67366244, 0.86084627,
#         0.63062358, 0.26674286, 0.37531122, 0.50604739, 0.8779638 ,
#         0.22391891, 0.7312733 , 0.45836587, 0.23988186, 0.28141729,
#         0.82626072, 0.58565028, 0.71440156, 0.82498275, 0.27347825,
#         0.70359856, 0.30193413, 0.78484403, 0.24272364, 0.46320541,
#         0.82035285, 0.82667402, 0.74608696, 0.11786157, 0.34441465,
#         0.61556339, 0.8097735 , 0.74759619, 0.91205966, 0.79801598,
#         0.68392332, 0.8772202 , 0.75509999, 0.65397358, 0.69792518,
#         0.73939006, 0.27658784, 0.83301347, 0.33299165, 0.34789922,
#         0.67308332, 0.08263558, 0.26267096, 0.82562894, 0.71988615,
#         0.71809142, 0.5990506 , 1.        , 0.85579616, 0.90383692,
#         0.72483723, 0.87135937, 0.47646715, 0.27057307, 0.82326139,
#         0.13524211, 0.75320962, 0.87576068, 0.86024129, 0.79337849,
#         0.79081377, 0.22748609, 0.7179789 , 0.25544609, 0.74999087,
#         0.44730968, 0.81454068, 0.63278945, 0.72351446, 0.14745095,
#         0.85297185, 0.43850201, 0.48344516, 0.58601561, 0.56027265,
#         0.2201191 , 0.14976025, 0.90711654, 0.7485737 , 0.71411522,
#         0.29231963, 0.72671206, 0.44558502, 0.71194436, 0.64893054,
#         0.42347104, 0.75713114, 0.86560407, 0.30030753, 0.62132103,
#         0.54826625, 0.76788158, 0.90057377, 0.71453631, 0.21815423,
#         0.80151141, 0.78623441]),
#  array([[1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.2571974e-02],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [2.1791530e-34],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [5.1003882e-18],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [6.2861013e-01],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [9.9096239e-01],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [2.8843380e-23],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [9.9902338e-01],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [0.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00],
#         [1.0000000e+00]], dtype=float32))
